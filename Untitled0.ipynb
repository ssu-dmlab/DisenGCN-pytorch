# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/연구실/Geonwoo Ko/Research/DisenGCN-pytorch
# !pip install -r ./requirements.txt
# %cd src
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/107r5K0_qzMzC2U5GN3KdxA907I9lnkmC/Geonwoo Ko/Research/DisenGCN-pytorch
# ...
#      |████████████████████████████████| 1.9 MB 8.2 MB/s
# ...
#      |████████████████████████████████| 57 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 87 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 93 kB/s
# ...
#      |████████████████████████████████| 76 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 78 kB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=6af04c9e8c650d7cfd1a9a12c6c8fe7a4dffff8acd6f2d1fe5d86b076bd9e6b5
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tqdm
# ...

# %%
# %cd /content/drive/.shortcut-targets-by-id/107r5K0_qzMzC2U5GN3KdxA907I9lnkmC/Geonwoo Ko/Research/DisenGCN-pytorch
# !python3 ./src/experiments/experiment.py
# Out:
# /content/drive/.shortcut-targets-by-id/107r5K0_qzMzC2U5GN3KdxA907I9lnkmC/Geonwoo Ko/Research/DisenGCN-pytorch
# 2021-08-08 09:16:00.660 | INFO     | main:main:73 - The main procedure has started with the following parameters:
# 2021-08-08 09:16:00.691 | INFO     | utils:log_param:26 - datadir             :                                         datasets/
# 2021-08-08 09:16:00.692 | INFO     | utils:log_param:26 - dataname            :                                              Cora
# 2021-08-08 09:16:00.692 | INFO     | utils:log_param:26 - device              :                                              cuda
# 2021-08-08 09:16:00.692 | INFO     | utils:log_param:26 - bidirect            :                                                 1
# 2021-08-08 09:16:00.692 | INFO     | utils:log_param:26 - seed                :                                                -1
# ...

# %%
function ClickConnect(){
    console.log("코랩 연결 끊김 방지"); 
    document.querySelector("colab-toolbar-button#connect").click() 
}
setInterval(ClickConnect, 60 * 1000)
# Out:
#   File "<ipython-input-3-b32b2eaebf57>", line 1
#     function ClickConnect(){
#                         ^
# SyntaxError: invalid syntax
